# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data (You will need to replace this with your actual data)
y1 = np.load('./Semantic-backdoorsaccuracy_(clip=100)green_car.npy')  # Blue line with square markers
y2 = np.load('./Semantic-backdoorsaccuracy_(clip=100)racing_car.npy') # Green line with triangle markers
y3 = np.load('./Semantic-backdoorsaccuracy_(clip=100)back_ground_wall.npy')  # Red line with circular markers
y4 = np.load('./Semantic-backdoorsaccuracy.npy')  # Dashed horizontal line
# Slice the arrays to exclude the first 1000 data points

y1 = y1[1000:]
y2 = y2[1000:]
y3 = y3[1000:]
# Plot the lines with different markers and styles
plt.plot(y1, color='blue', marker='s',markevery=15, label='green_car')  # Square markers
plt.plot(y2, color='green', marker='^',markevery=15, label='racing_car')  # Triangle markers
plt.plot(y3, color='red', marker='o',markevery=15, label='back_ground_wall')  # Circle markers
plt.plot(y4, color='black', linestyle='--', label='total')  # Dashed line

# Add labels and title
plt.xlabel('Rounds since attack')
plt.ylabel('Y')
plt.title('Performance over Rounds')

# Customize the plot for specific marker placements
plt.legend()

# Show the plot
plt.show()
